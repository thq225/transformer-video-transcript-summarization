# %%
full_transcript = """
Hello everyone, my name is Simon Chen and today with my partner Matt Olsen we'll be discussing our final project milestone. We've called it who has jo stability, a changed approach. We'll be diving deep into why we decided to shif from the Beijian hierarchal model we initially proposed to a bootstrappin method. So first we'll go over a quick project summary and then we'll discus our Beijing approach and then we'll conclude with some of our bootstrappin findings and other results. Now I'll pass it off to Matt to discus some of our project that we've done this far >> First for a brief review, we we've seen that unemployment has increased in th US over the last few years affecting individuals differently dependent o their demographic groups or their education level and uh industry o previous employment. Now, uh, our goal initially was to quantify jo uncertainty with a Beijian hierarchical model framework to identify who's likel to be unemployed. First, we cleaned our data set as par of our previous milestone. And we now have more uh workable variables uh suc as industry code, um education code, race, sex, and age groups, i individuals are in the labor force or not, and if they're unemployed or not And uh we initially wanted to do analysis on income levels and u reemployment times but those were not uh that was not data that was available t us um in the Bureau of Labor Statistics basic monthly census >> Perfect. So thank you Matt. I'll discuss some of our findings when we did ou initial Beijing approach. So to quickly give an idea of what happened w initially were trying to approach the the Beijian hierarchal model with  single factor or two factor kind of attribution. So in that sense when w did our EDA we took a look at things like which industries were most impacte uh which education levels were most resilient to unemployment. So with tha understanding this is the kind of baseline that I want everyone t understand. When we took a look at the data set from 2020 to 2024 our nationa unemployment rate was about 4.97%. This is higher than it is currently toda which is about 4.3%. Um and that is because most of this outside uh outsize effect was due to COVID. So that shock really increased a lot of unemploymen in the early years of 2020 to 2021. Um but it has still steadily increase since 2022. So first let's quickly summarize what w found when we just took a look at age. So in our hypothesis here we want t understand which age groups were most affected by unemployment. As you ca see, we can have a rough U-shaped distribution where younger groups 16 t 24 are most affected as well as some seniors as you approach the 55 plus ag range. This illustrates to us that there is some impact when it comes to jo seniority and how long you've been in the market. These are factors that d enhance your capability to be remployed. And so we see a a greater risk for thos who are still very young in their careers Next, we want to take a look at how age interacted with sex. So, as you can se in the graph here, we see that men typically have, especially younger men have a higher unemployment rate in the 16 to 34 age range. But as they ge older, both of them tend to roughly stabilize. This is interesting to u because it shows that certain industries that are more predominantly focused o men may have been more affected, such as construction and manufacturing, which w did see in our EDA. And then finally, this heat map was kin of the critical point when we took a look at our Beijing approach. B comparing age and race, we really were able to centralize and isolate whic subgroups were at the highest risk. So, if you look at the left column, you'l see that the youngest age range for black and native Native America minority groups are most affected and most likely to remain unemployed Furthermore, racial groups such as white or Asians are a little bit mor resilient and that holds true even as they get older. So 25 plus. This is ver concerning for us because it illustrates that there are key subgroups within ou data that are unduly affected compared to the others And so these general conclusions that we found from our Beijian approach can b wrapped up in three major points. The first is that unemployment is not just  function of age or sex or race, but a combination of all of them Additionally, our data suggests that we need to find some way to help suppor those higher risk demographics. And finally, the Beijian model with the 95 credible interval. While it does produce some kind of uncertainty aware estimate it is still a little bit difficult in the context of our data set, whic follows through to why we ultimately decided to switch from the Beijia hierarchal model to a more bootstrapping method. Namely, the data set that w were utilizing was simply too large and complex. For one, we had millions o observations. And within those observations, there were a lot o subcategories, whether it be education or industry level. As a result of that we have really sparse and small subgroups that are very difficult t account for. Furthermore, this nominal data while we treat it as categorical it doesn't have an inherent order. So when comparing it with Beijian model, i becomes unduly time consuming if we were trying to model it. Ultimately t summarize, we found that the multinnomial likelihood display reall strong sensitivity and can sometimes lack clarity. So we looked for a littl bit of a better method in terms of our use case and that's how we settled o bootstrapping. So here's a table that compares the major differences and on of the main differences is the core mechanism for the Bayian model. We hav to rely on prior distributions to try to stabilize the estimate to get th posterior distribution. Whereas with bootstrapping, we can simply resampl without replacement, which simply means that we're just simulating a thousand or dozens of thousands of pseudo samples to try to build out an empirica distribution of the population. Furthermore, when it comes to a assumption, the Beijian model needs to rely on a likelihood function, in whic case we assume the binomial version, but ultimately we would need multinnomial which is again the limitation in the assumptions that we mentioned earlier Whereas with bootstrapping, because it's nonparametric, we don't have to mak those assumptions. And then finally for the computational cost the Beijian mode is extremely high. Monte Carlo Marov chains can be very costly and difficul to tune. So that's why we decided with bootstrapping because it's much faste when running those iterations. It would be a little bit more effective a achieving our goal while being cheaper. So now I'll take let Matt take on th bootstrapping findings. So, one uh thing to note that we se that is very consistent with our preliminary findings is the U-shape curve in the bootstrap uh unemployment rate as there was in the bas unemployment rate in age groups. And we see yet again that the youngest ag group has the highest unemployment rate. And when looking at bootstra unemployment rate by sex, we see uh that it's consistent yet again with ou previous findings. And we see that uh female individuals have a lowe unemployment rate and than male individuals overall slightly Now when we uh looked at looking at the bootstrap unemployment rate on race o individuals, we see that there a couple groups like Native Americans and blac people that are um disproportionately affected uh and in especially i comparison to white and Asian groups that have a much lower unemployment rat in comparison to them. Now when we look at the unemploymen rate by education level, we see a general consistent trend that highe education consistently yields lower unemployment rates. This is with th exception of um education levels less than 10th grade. And this is due to ou data set having um consisting of individuals 16 and older. So, we hav some 16-year-olds in 10th grade, and those that are uh have less than 10t grade education are older individuals. And we've already seen that there's a u higher a lower unemployment rate in the more uh old an individual is Now, we'd seen previously that in our heat map that um the youngest age grou of intersection with black people had a very high unemployment rate. And w wanted to see what uh the bootstrap unemployment rate if that uh rati between black people and people of other races was constant between the younges age group and all other age groups. And we see that it is constant. And w wanted to check on if these findings are consistent for other races as well And here we see for white people compared with all other races betwee the youngest age group and all other age groups that it is consistent yet agai and benefiting white people. And this paints a grim picture of race in th United States uh in an inescapable inherent advantage or disadvantage tha is ever present. >> Thank you Matt. So now let's wrap this all up and synthesize what we have found thus far. So first we'd like to talk a little bit about our key findings throughout this project. The main idea that we uh synthesized was that the unemployment's uncertainty is concentrated in specific demographic intersections. So one primary effect that we already mentioned is age. Age is an extremely strong predictor of unemployment probability and its interaction with another variable specifically race is extremely high risk factor. What we found was that in comparison to something like age and education or age and uh industry, age and race was where it was most concentrated in terms of these subgroups that were most outsized. So the statistical key idea that we settled on here is that the true unemployment probability ranges for the high-risisk groups do not overlap with those of the low-risisk groups which lends higher credibility and confidence to this observed disparity. So the choice of using bootstrapping to have those 95% confidence intervals is what allow us to make this kind of claim. Now given that these findings support our thesis, how can we transfer this into some kind of policy recommendation? Well, we settled on targeted interventions. Mainly we want to try to address where the intersections of risk are most prominent. So one example could be to suggest a high-risisk youth program. We saw that racial minorities that are younger face much more unemployment risk and therefore implementing some kind of federally funded program to help these individuals may be prudent. Again, we also noticed that in terms of middle careers, men were typically a little bit more affected than women. Now, we wouldn't want to immedately suggest that necessarily men need more resources than women, but perhaps there are different avenues that we could approach. One example could be to try to improve the education access to all genders. We saw how education was sort of a shield towards unemployment the higher and more advanced you received of an education. So in that sense and a a a suggestion for better education may be more prudent. And then finally we wanted to make a suggestion for the data transparency mainly that BLS and CPS do not provide very granular data to facilitate these kind of interaction analyses. For one, they don't really provide all the details such as the wages or the reemployment duration, and having more than just a once a year census could be very helpful. Understandably, that would be much more costly. And additionally, we can't rely that everyone will respond, but we thought this would be a suggestion worth putting out there. Finally, we just wanted to discuss some of our project limitations and what we could have improved. So one, for our data, we had cross-sectional data, meaning that these were snapshots of individuals at a certain point in time rather than kind of a quarterly time series analysis, and that limits our ability to make definitive claims about causality. Furthermore, for the model, we definitely overlook some of the more important information such as job satisfaction, job quality, or even wage recovery or wage improvement. These are all things that are really important in the decision to become re-employed or stay unemployed. And by overlooking that, these are some things that we could have maybe improved the accuracy about. And then finally, in terms of the statistical method, as we've mentioned, bootstrapping is simply not as feature relevant as a true multinnomial Beijian hierarchal model. So if we were to suggest improvements, we would encourage others to try to attempt what we did and to try to implement that multinnomial Beijian model. This could be done through a binomial logic link. Additionally, if the BLS or CPS data set were to be improved to include metrics such as time until full-time reemployment, those could be implemented to improve the model. Again, this is something that could be done in the future, but our overall summary is that we believe that we need to understand which groups are marginalized, which groups are at highest risk, and how do we improve the likelihood that those individuals become re-employed. Thank you very much. We hope you enjoyed our presentation, and let us know if you have any questions.
"""

# %%
import re
import time
from transformers import BartTokenizerFast, BartForConditionalGeneration

# ========= 1) Load model =========
MODEL_DIR = "../outputs/qmsum_bart_baseline/best_model"

print("Loading tokenizer...")
tokenizer = BartTokenizerFast.from_pretrained(MODEL_DIR)

print("Loading model...")
model = BartForConditionalGeneration.from_pretrained(MODEL_DIR)

print("Model loaded successfully.\n")


# ========= 2) Inputs =========
# query = "What are the main findings and conclusions of this presentation?"
# section_query = (
#     "What key ideas or findings are discussed in this part of the lecture? "
#     "Write a concise summary of the content."
# )
section_query = "Write a concise summary of the important points in this section."

# ========= 3) Helpers =========

def clean_text(text):
    text = text.replace(">>", " ")
    text = re.sub(r"\s+", " ", text).strip()
    return text


def split_into_sentence_chunks(text, tokenizer, max_tokens=320):
    print("Cleaning transcript...")
    text = clean_text(text)

    sentences = re.split(r'(?<=[.!?])\s+', text)
    sentences = [s.strip() for s in sentences if s.strip()]

    print(f"Total sentences detected: {len(sentences)}")

    chunks = []
    current = []

    for sent in sentences:
        candidate = " ".join(current + [sent])
        token_count = len(tokenizer.encode(candidate, add_special_tokens=False))

        if token_count > max_tokens and current:
            chunks.append(" ".join(current))
            current = [sent]
        else:
            current.append(sent)

    if current:
        chunks.append(" ".join(current))

    print(f"Total chunks created: {len(chunks)}\n")

    for i,c in enumerate(chunks):
        tokens = len(tokenizer.encode(c))
        print(f"Chunk {i+1} token length: {tokens}")

    print()
    return chunks


def generate_summary(query, text, tokenizer, model,
                     input_max_length=512,
                     output_max_length=120,
                     output_min_length=40):

    start_time = time.time()

    input_text = f"query: {query}\n\ntranscript:\n{text}"

    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        max_length=input_max_length,
        truncation=True
    )

    input_tokens = inputs["input_ids"].shape[1]

    print(f"Input tokens: {input_tokens}")

    summary_ids = model.generate(
        **inputs,
        max_length=output_max_length,
        min_length=output_min_length,
        num_beams=4,
        no_repeat_ngram_size=3,
        length_penalty=1.0,
        early_stopping=True
    )

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True).strip()

    generation_time = round(time.time() - start_time, 2)

    print(f"Generated tokens: {len(summary_ids[0])}")
    print(f"Generation time: {generation_time}s\n")

    # Cut incomplete sentence
    if not summary.endswith((".", "!", "?")):
        last_punc = max(summary.rfind("."), summary.rfind("!"), summary.rfind("?"))
        if last_punc > 40:
            summary = summary[:last_punc + 1]

    return summary


# ========= 4) Pipeline =========

print("Splitting transcript into chunks...\n")

chunks = split_into_sentence_chunks(full_transcript, tokenizer)

chunk_summaries = []

print("Starting chunk summarization...\n")

for i, chunk in enumerate(chunks):

    print("="*60)
    print(f"Processing chunk {i+1}/{len(chunks)}")

    summary = generate_summary(
        query=section_query,
        text=chunk,
        tokenizer=tokenizer,
        model=model,
        output_max_length=100,
        output_min_length=30
    )

    print("Chunk summary:")
    print(summary)
    print()

    chunk_summaries.append(summary)


# ========= 5) Final summary =========

print("\n" + "="*80)
print("Combining chunk summaries for final summarization...\n")

combined_text = "\n".join(
    [f"Section {i+1}: {s}" for i,s in enumerate(chunk_summaries)]
)

def generate_long_summary(text, tokenizer, model):
        prompt = f"""
    Rewrite the following lecture summary so that it is slightly shorter and clearer.
    Keep all important ideas and preserve the structure of the sections.
    Do not remove major findings or conclusions.

    {text}
    """

        inputs = tokenizer(
            prompt,
            return_tensors="pt",
            max_length=1024,
            truncation=True
        )

        summary_ids = model.generate(
            **inputs,
            max_length=450,      # much longer
            min_length=250,      # force long output
            num_beams=4,
            length_penalty=1.0,
            no_repeat_ngram_size=3,
            early_stopping=True
        )

        return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

final_summary = generate_summary(
    query="What are the main findings, methods, and conclusions of the full lecture?",
    text=combined_text,
    tokenizer=tokenizer,
    model=model,
    output_max_length=5000,
    output_min_length=250
)
# final_summary = generate_long_summary(
#     combined_text,
#     tokenizer,
#     model
# )

print(final_summary)
print("="*80)
print("FINAL SUMMARY\n")
print(final_summary)

print("\nPipeline finished successfully.")
# Out:
# Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading tokenizer...
# Loading model...
# Loading weights:   0%|          | 0/358 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Model loaded successfully.
#
# Splitting transcript into chunks...
#
# Cleaning transcript...
# Total sentences detected: 100
# Total chunks created: 9
#
# Chunk 1 token length: 319
# Chunk 2 token length: 320
# Chunk 3 token length: 311
# ...

# %%
from IPython.display import display, Markdown

display(Markdown(final_summary))
# Out:
# According to Simon Chen, unemployment in the US has increased over the last few years. He explained that they had seen that unemployment has increased in the past few years affecting individuals differently dependent on their education level and previous employment. They had to change their model to a bootstrappin method. They concluded that the data suggests that we need to find some way to help those higher risk demographics. To do that, they would need to improve the education access to all genders. To conclude, they had a cross-sectional data set from 2020 to 2024. To begin with, the data set was about 4.97%. This is higher than it is currently. To complete this, they have a detailed set of summaries and summaries of the summaries, respectively, respectively. The summaries in the summ summaries respectively, etc. In terms of their summaries for the summary summaries. The corresponding summaries with summaries etc. etc. respectively respectively, and respectively, in the summary s
# ...

# %%
display(Markdown(combined_text))
# Out:
# Section 1: According to Simon Chen, unemployment in the US has increased over the last few years. He explained that they had seen that unemployment has increased in the past few years affecting individuals differently dependent on their education level and previous employment. They had to change their model to a bootstrappin method.
# Section 2: According to the data set from 2020 to 2024, unemployment in the U.S. was about 4.97%. This is higher than it is currently. Currently, it is about 4%.
# Section 3: According to the data, unemployment is not just function of age or sex or race, but a combination of all of them. Also, the data suggests that we need to find some way to help those higher risk demographics.
# ...

# %%
def chunk_text_by_sentences(text, tokenizer, max_tokens=400):
    sentences = re.split(r'(?<=[.!?])\s+', text)
    chunks = []
    current_chunk = []

    for sentence in sentences:
        candidate = " ".join(current_chunk + [sentence])
        token_count = len(tokenizer.encode(candidate, add_special_tokens=False))

        if token_count > max_tokens and current_chunk:
            chunks.append(" ".join(current_chunk))
            current_chunk = [sentence]
        else:
            current_chunk.append(sentence)

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks

def summarize_chunk(query, chunk, tokenizer, model,
                    input_max_length=512,
                    output_max_length=120,
                    output_min_length=40):
    input_text = f"query: {query}\n\ntranscript:\n{chunk}"

    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        max_length=input_max_length,
        truncation=True
    )

    summary_ids = model.generate(
        **inputs,
        max_length=output_max_length,
        min_length=output_min_length,
        num_beams=4,
        length_penalty=1.0,
        no_repeat_ngram_size=3,
        early_stopping=True
    )

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)


def summarize_final(query, text, tokenizer, model):
    input_text = f"query: {query}\n\ntranscript:\n{text}"

    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        max_length=512,
        truncation=True
    )

    summary_ids = model.generate(
        **inputs,
        max_length=180,
        min_length=80,
        num_beams=4,
        length_penalty=1.1,
        no_repeat_ngram_size=3,
        early_stopping=True
    )

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

def summarize_full_transcript(query, transcript, tokenizer, model,
                              chunk_max_tokens=400):
    chunks = chunk_text_by_sentences(transcript, tokenizer, max_tokens=chunk_max_tokens)
    print(f"Number of chunks: {len(chunks)}")

    chunk_summaries = []
    for i, chunk in enumerate(chunks):
        print(f"Summarizing chunk {i+1}/{len(chunks)}...")
        chunk_summary = summarize_chunk(query, chunk, tokenizer, model)
        chunk_summaries.append(chunk_summary)

    combined_summary_text = "\n".join(
        [f"Chunk {i+1}: {s}" for i, s in enumerate(chunk_summaries)]
    )

    final_summary = summarize_final(
        query="What are the main findings, methods, and conclusions of this presentation?",
        text=combined_summary_text,
        tokenizer=tokenizer,
        model=model
    )

    return final_summary, chunk_summaries

# %%
query = "What are the main findings and conclusions of this presentation?"

full_transcript = """
Hello everyone, my name is Simon Chen and today with my partner Matt Olsen we'll be discussing our final project milestone. We've called it who has jo stability, a changed approach. We'll be diving deep into why we decided to shif from the Beijian hierarchal model we initially proposed to a bootstrappin method. So first we'll go over a quick project summary and then we'll discus our Beijing approach and then we'll conclude with some of our bootstrappin findings and other results. Now I'll pass it off to Matt to discus some of our project that we've done this far >> First for a brief review, we we've seen that unemployment has increased in th US over the last few years affecting individuals differently dependent o their demographic groups or their education level and uh industry o previous employment. Now, uh, our goal initially was to quantify jo uncertainty with a Beijian hierarchical model framework to identify who's likel to be unemployed. First, we cleaned our data set as par of our previous milestone. And we now have more uh workable variables uh suc as industry code, um education code, race, sex, and age groups, i individuals are in the labor force or not, and if they're unemployed or not And uh we initially wanted to do analysis on income levels and u reemployment times but those were not uh that was not data that was available t us um in the Bureau of Labor Statistics basic monthly census >> Perfect. So thank you Matt. I'll discuss some of our findings when we did ou initial Beijing approach. So to quickly give an idea of what happened w initially were trying to approach the the Beijian hierarchal model with  single factor or two factor kind of attribution. So in that sense when w did our EDA we took a look at things like which industries were most impacte uh which education levels were most resilient to unemployment. So with tha understanding this is the kind of baseline that I want everyone t understand. When we took a look at the data set from 2020 to 2024 our nationa unemployment rate was about 4.97%. This is higher than it is currently toda which is about 4.3%. Um and that is because most of this outside uh outsize effect was due to COVID. So that shock really increased a lot of unemploymen in the early years of 2020 to 2021. Um but it has still steadily increase since 2022. So first let's quickly summarize what w found when we just took a look at age. So in our hypothesis here we want t understand which age groups were most affected by unemployment. As you ca see, we can have a rough U-shaped distribution where younger groups 16 t 24 are most affected as well as some seniors as you approach the 55 plus ag range. This illustrates to us that there is some impact when it comes to jo seniority and how long you've been in the market. These are factors that d enhance your capability to be remployed. And so we see a a greater risk for thos who are still very young in their careers Next, we want to take a look at how age interacted with sex. So, as you can se in the graph here, we see that men typically have, especially younger men have a higher unemployment rate in the 16 to 34 age range. But as they ge older, both of them tend to roughly stabilize. This is interesting to u because it shows that certain industries that are more predominantly focused o men may have been more affected, such as construction and manufacturing, which w did see in our EDA. And then finally, this heat map was kin of the critical point when we took a look at our Beijing approach. B comparing age and race, we really were able to centralize and isolate whic subgroups were at the highest risk. So, if you look at the left column, you'l see that the youngest age range for black and native Native America minority groups are most affected and most likely to remain unemployed Furthermore, racial groups such as white or Asians are a little bit mor resilient and that holds true even as they get older. So 25 plus. This is ver concerning for us because it illustrates that there are key subgroups within ou data that are unduly affected compared to the others And so these general conclusions that we found from our Beijian approach can b wrapped up in three major points. The first is that unemployment is not just  function of age or sex or race, but a combination of all of them Additionally, our data suggests that we need to find some way to help suppor those higher risk demographics. And finally, the Beijian model with the 95 credible interval. While it does produce some kind of uncertainty aware estimate it is still a little bit difficult in the context of our data set, whic follows through to why we ultimately decided to switch from the Beijia hierarchal model to a more bootstrapping method. Namely, the data set that w were utilizing was simply too large and complex. For one, we had millions o observations. And within those observations, there were a lot o subcategories, whether it be education or industry level. As a result of that we have really sparse and small subgroups that are very difficult t account for. Furthermore, this nominal data while we treat it as categorical it doesn't have an inherent order. So when comparing it with Beijian model, i becomes unduly time consuming if we were trying to model it. Ultimately t summarize, we found that the multinnomial likelihood display reall strong sensitivity and can sometimes lack clarity. So we looked for a littl bit of a better method in terms of our use case and that's how we settled o bootstrapping. So here's a table that compares the major differences and on of the main differences is the core mechanism for the Bayian model. We hav to rely on prior distributions to try to stabilize the estimate to get th posterior distribution. Whereas with bootstrapping, we can simply resampl without replacement, which simply means that we're just simulating a thousand or dozens of thousands of pseudo samples to try to build out an empirica distribution of the population. Furthermore, when it comes to a assumption, the Beijian model needs to rely on a likelihood function, in whic case we assume the binomial version, but ultimately we would need multinnomial which is again the limitation in the assumptions that we mentioned earlier Whereas with bootstrapping, because it's nonparametric, we don't have to mak those assumptions. And then finally for the computational cost the Beijian mode is extremely high. Monte Carlo Marov chains can be very costly and difficul to tune. So that's why we decided with bootstrapping because it's much faste when running those iterations. It would be a little bit more effective a achieving our goal while being cheaper. So now I'll take let Matt take on th bootstrapping findings. So, one uh thing to note that we se that is very consistent with our preliminary findings is the U-shape curve in the bootstrap uh unemployment rate as there was in the bas unemployment rate in age groups. And we see yet again that the youngest ag group has the highest unemployment rate. And when looking at bootstra unemployment rate by sex, we see uh that it's consistent yet again with ou previous findings. And we see that uh female individuals have a lowe unemployment rate and than male individuals overall slightly Now when we uh looked at looking at the bootstrap unemployment rate on race o individuals, we see that there a couple groups like Native Americans and blac people that are um disproportionately affected uh and in especially i comparison to white and Asian groups that have a much lower unemployment rat in comparison to them. Now when we look at the unemploymen rate by education level, we see a general consistent trend that highe education consistently yields lower unemployment rates. This is with th exception of um education levels less than 10th grade. And this is due to ou data set having um consisting of individuals 16 and older. So, we hav some 16-year-olds in 10th grade, and those that are uh have less than 10t grade education are older individuals. And we've already seen that there's a u higher a lower unemployment rate in the more uh old an individual is Now, we'd seen previously that in our heat map that um the youngest age grou of intersection with black people had a very high unemployment rate. And w wanted to see what uh the bootstrap unemployment rate if that uh rati between black people and people of other races was constant between the younges age group and all other age groups. And we see that it is constant. And w wanted to check on if these findings are consistent for other races as well And here we see for white people compared with all other races betwee the youngest age group and all other age groups that it is consistent yet agai and benefiting white people. And this paints a grim picture of race in th United States uh in an inescapable inherent advantage or disadvantage tha is ever present. >> Thank you Matt. So now let's wrap this all up and synthesize what we have found thus far. So first we'd like to talk a little bit about our key findings throughout this project. The main idea that we uh synthesized was that the unemployment's uncertainty is concentrated in specific demographic intersections. So one primary effect that we already mentioned is age. Age is an extremely strong predictor of unemployment probability and its interaction with another variable specifically race is extremely high risk factor. What we found was that in comparison to something like age and education or age and uh industry, age and race was where it was most concentrated in terms of these subgroups that were most outsized. So the statistical key idea that we settled on here is that the true unemployment probability ranges for the high-risisk groups do not overlap with those of the low-risisk groups which lends higher credibility and confidence to this observed disparity. So the choice of using bootstrapping to have those 95% confidence intervals is what allow us to make this kind of claim. Now given that these findings support our thesis, how can we transfer this into some kind of policy recommendation? Well, we settled on targeted interventions. Mainly we want to try to address where the intersections of risk are most prominent. So one example could be to suggest a high-risisk youth program. We saw that racial minorities that are younger face much more unemployment risk and therefore implementing some kind of federally funded program to help these individuals may be prudent. Again, we also noticed that in terms of middle careers, men were typically a little bit more affected than women. Now, we wouldn't want to immedately suggest that necessarily men need more resources than women, but perhaps there are different avenues that we could approach. One example could be to try to improve the education access to all genders. We saw how education was sort of a shield towards unemployment the higher and more advanced you received of an education. So in that sense and a a a suggestion for better education may be more prudent. And then finally we wanted to make a suggestion for the data transparency mainly that BLS and CPS do not provide very granular data to facilitate these kind of interaction analyses. For one, they don't really provide all the details such as the wages or the reemployment duration, and having more than just a once a year census could be very helpful. Understandably, that would be much more costly. And additionally, we can't rely that everyone will respond, but we thought this would be a suggestion worth putting out there. Finally, we just wanted to discuss some of our project limitations and what we could have improved. So one, for our data, we had cross-sectional data, meaning that these were snapshots of individuals at a certain point in time rather than kind of a quarterly time series analysis, and that limits our ability to make definitive claims about causality. Furthermore, for the model, we definitely overlook some of the more important information such as job satisfaction, job quality, or even wage recovery or wage improvement. These are all things that are really important in the decision to become re-employed or stay unemployed. And by overlooking that, these are some things that we could have maybe improved the accuracy about. And then finally, in terms of the statistical method, as we've mentioned, bootstrapping is simply not as feature relevant as a true multinnomial Beijian hierarchal model. So if we were to suggest improvements, we would encourage others to try to attempt what we did and to try to implement that multinnomial Beijian model. This could be done through a binomial logic link. Additionally, if the BLS or CPS data set were to be improved to include metrics such as time until full-time reemployment, those could be implemented to improve the model. Again, this is something that could be done in the future, but our overall summary is that we believe that we need to understand which groups are marginalized, which groups are at highest risk, and how do we improve the likelihood that those individuals become re-employed. Thank you very much. We hope you enjoyed our presentation, and let us know if you have any questions.
"""

final_summary, chunk_summaries = summarize_full_transcript(
    query=query,
    transcript=full_transcript,
    tokenizer=tokenizer,
    model=model,
    chunk_max_tokens=400
)

print("\nFINAL SUMMARY:\n")
print(final_summary)

# %%
from IPython.display import display, Markdown

display(Markdown(final_summary))
